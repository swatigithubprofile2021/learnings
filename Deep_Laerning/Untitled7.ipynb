# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv('test_data.csv')

# Generate random regressor
np.random.seed(0)  # For reproducibility
data['random_regressor'] = np.random.rand(len(data))

# Split data into train and test sets
train, test = train_test_split(data, test_size=0.2, shuffle=False)

# Define features and target variable
features = ['random_regressor']
target = 'QTY'

# Train the forecasting model
model = RandomForestRegressor(n_estimators=100, random_state=0)
model.fit(train[features], train[target])

# Make predictions
predictions = model.predict(test[features])

# Evaluate the model
mse = mean_squared_error(test[target], predictions)
print('Mean Squared Error:', mse)

# Visualize the forecast
plt.plot(test.index, test[target], label='Actual')
plt.plot(test.index, predictions, label='Forecast')
plt.xlabel('Time')
plt.ylabel('QTY')
plt.title('Random Forest Forecast')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 1218098781.114453
