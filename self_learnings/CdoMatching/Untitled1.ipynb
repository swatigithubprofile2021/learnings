# %%
@app.post('/UkBhulekh&PmKisanMatching/Matching_CDO',tags=["Haritkranti APIs"])  
async def getPmMatchedData(villageCodeList:List[str],ip: Optional[str] = "127.0.0.1",databaseName: Optional[str] = "haritkranti06032021",uniqueFarmerCollection: Optional[str] = "UniqueFarmers",pmKisanDataCollection: Optional[str] = "pmKisanData",pmKisanMatchingCollection: Optional[str] = "pmKisanMatching"):
    def matching(pj,bj):
        s = Soundex()
        m = Metaphone()
        r = RefinedSoundex()
        mat = ""
        pjz = pj.lower().replace("a.","").replace('md.','').replace("mohd ","").replace('muhammad','').replace('mohammad','').replace('mohammed','').replace('muhammed','').replace('abdul ','').replace('m / s ','').replace('m/s ','').replace('director ','').replace('nideshak ','').replace('general ','').replace('manager ','').replace('finance ','').replace('proprietor ','').replace('managing ','').replace('chairman ','').replace('adhikrt ','').replace('hastakshari ','').replace('Phoorakan','Furkan').replace('Pradip','Pradeep').replace('Sarapharaj','Sarfaraz').replace('Rupakishor','Rupkishor').replace('Ashik','Ashiq').replace('Khurashid','Khurasheed').replace('Aphajad ','afjad').replace('Jagadish','Jagdish').replace('Krrishn','Krishn').replace('0','.').replace('Mau.','Md. ').replace('Mu.','Md. ').replace('Julphukar','Zulfukar').replace('Raphik','Rafiq').replace('ॉ','n').replace('Nur','Noor').replace('.D','d').replace('Chakamarg','Chakmarg').replace('Phaijan','Faizan').replace('Rahaman','Rahman').replace('Chakarod','Chakrod').replace('Sviti','Sweety').replace('ua','uya').replace('Aphasana','Afsana').replace('Ejaj','Ejaz').replace('Shahanavaj','Shahnavaj').replace('Virendr','Virendra').replace('Krrishna','Krishn').replace('Meharaban','Meharban').replace('Rukasana','Ruksana').replace('Juber','Zuber').replace('Kamarej','Kamrej').replace('Vahida','Waheed').replace('Mahabub','Mahboob').replace('Jan','Jaan').replace('Jahir','Zaheer').replace('Dipak','Deepak').replace('Urf','or').replace('Ghanashyam','Ghanshyam').replace('Hashamat','Hashmat').replace('Akhatar','Akhtar').replace('Rajakumar','Rajkumar').replace('Begaraj','Begraj').replace('Haphij','Hafiz').replace('Ahatamam','Ahatmam').replace('Nussever','Nusavvar').replace('Janaki','Janki').replace('narayan',' narayan').replace("  ",' ').replace(".","").strip()
        bjz = bj.lower().replace("a.","").replace('md.','').replace("mohd ","").replace('muhammad','').replace('mohammad','').replace('mohammed','').replace('muhammed','').replace('abdul ','').replace('m / s ','').replace('m/s ','').replace('director ','').replace('nideshak ','').replace('general ','').replace('manager ','').replace('finance ','').replace('proprietor ','').replace('managing ','').replace('chairman ','').replace('adhikrt ','').replace('hastakshari ','').replace('Phoorakan','Furkan').replace('Pradip','Pradeep').replace('Sarapharaj','Sarfaraz').replace('Rupakishor','Rupkishor').replace('Ashik','Ashiq').replace('Khurashid','Khurasheed').replace('Aphajad ','afjad').replace('Jagadish','Jagdish').replace('Krrishn','Krishn').replace('0','.').replace('Mau.','Md. ').replace('Mu.','Md. ').replace('Julphukar','Zulfukar').replace('Raphik','Rafiq').replace('ॉ','n').replace('Nur','Noor').replace('.D','d').replace('Chakamarg','Chakmarg').replace('Phaijan','Faizan').replace('Rahaman','Rahman').replace('Chakarod','Chakrod').replace('Sviti','Sweety').replace('ua','uya').replace('Aphasana','Afsana').replace('Ejaj','Ejaz').replace('Shahanavaj','Shahnavaj').replace('Virendr','Virendra').replace('Krrishna','Krishn').replace('Meharaban','Meharban').replace('Rukasana','Ruksana').replace('Juber','Zuber').replace('Kamarej','Kamrej').replace('Vahida','Waheed').replace('Mahabub','Mahboob').replace('Jan','Jaan').replace('Jahir','Zaheer').replace('Dipak','Deepak').replace('Urf','or').replace('Ghanashyam','Ghanshyam').replace('Hashamat','Hashmat').replace('Akhatar','Akhtar').replace('Rajakumar','Rajkumar').replace('Begaraj','Begraj').replace('Haphij','Hafiz').replace('Ahatamam','Ahatmam').replace('Nussever','Nusavvar').replace('Janaki','Janki').replace('narayan',' narayan').replace("  ",' ').replace(".","").strip()
        p1 = str(pjz.split("//")[0].strip().split(" ")[0].lower())
        print("p1----",p1)
        p2 = str(pjz.split("//")[1].strip().split(" ")[0].lower())
        print("p2----",p1)

        b1 = str(bjz.split("//")[0].strip().split(" ")[0].lower())
        print("b1----",p1)

        b2 = str(bjz.split("//")[1].strip().split(" ")[0].lower())
        print("b2----",p1)
        if len(p1) <3:
            p1 = "No Data"
        if len(p2) <3:
            p2 = "No Data"
        if len(b1) <3:
            b1 = "No Data"
        if len(b2) <3:
            b2 = "No Data"
        if str(pjz).replace(" ",'').lower() == str(bjz).replace(" ",'').lower():
            mat = "Matched"
            print(" in first condition of if Matched")
        elif (pjz.split("//")[0].split(" ")[0].lower() == bjz.split("//")[0].split(" ")[0].lower()) and (pjz.split("//")[1].split(" ")[0].lower() == bjz.split("//")[1].split(" ")[0].lower()):
            mat = "Matched"
            print("in second condition of if matched")
        elif p2 != "No Data":
            if s.sounds_like(p1,b1) and (s.sounds_like(p2,b2) or (m.distance(p2,b2) <2 and r.distance(p2,b2) <2 and s.phonetics(p2) == s.phonetics(b2))) :
                print("if father name is present")
                mat = "Matched"
        elif p2 == "No Data":
            if str(pjz.split("//")[0].strip()).lower() == str(bjz.split("//")[0].strip()).lower():
                print("if father name is  not present")

                mat = "Matched"
        return mat

    def matchingadv(pj,bj):
        s = Soundex()
        m = Metaphone()
        r = RefinedSoundex()
        mat = ""
        pjz = pj.lower().replace("a.","").replace('md.','').replace("mohd ","").replace('muhammad','').replace('mohammad','').replace('mohammed','').replace('muhammed','').replace('abdul ','').replace('m / s ','').replace('m/s ','').replace('director ','').replace('nideshak ','').replace('general ','').replace('manager ','').replace('finance ','').replace('proprietor ','').replace('managing ','').replace('chairman ','').replace('adhikrt ','').replace('hastakshari ','').replace('Phoorakan','Furkan').replace('Pradip','Pradeep').replace('Sarapharaj','Sarfaraz').replace('Rupakishor','Rupkishor').replace('Ashik','Ashiq').replace('Khurashid','Khurasheed').replace('Aphajad ','afjad').replace('Jagadish','Jagdish').replace('Krrishn','Krishn').replace('0','.').replace('Mau.','Md. ').replace('Mu.','Md. ').replace('Julphukar','Zulfukar').replace('Raphik','Rafiq').replace('ॉ','n').replace('Nur','Noor').replace('.D','d').replace('Chakamarg','Chakmarg').replace('Phaijan','Faizan').replace('Rahaman','Rahman').replace('Chakarod','Chakrod').replace('Sviti','Sweety').replace('ua','uya').replace('Aphasana','Afsana').replace('Ejaj','Ejaz').replace('Shahanavaj','Shahnavaj').replace('Virendr','Virendra').replace('Krrishna','Krishn').replace('Meharaban','Meharban').replace('Rukasana','Ruksana').replace('Juber','Zuber').replace('Kamarej','Kamrej').replace('Vahida','Waheed').replace('Mahabub','Mahboob').replace('Jan','Jaan').replace('Jahir','Zaheer').replace('Dipak','Deepak').replace('Urf','or').replace('Ghanashyam','Ghanshyam').replace('Hashamat','Hashmat').replace('Akhatar','Akhtar').replace('Rajakumar','Rajkumar').replace('Begaraj','Begraj').replace('Haphij','Hafiz').replace('Ahatamam','Ahatmam').replace('Nussever','Nusavvar').replace('Janaki','Janki').replace('narayan',' narayan').replace("  ",' ').replace(".","").strip()
        bjz = bj.lower().replace("a.","").replace('md.','').replace("mohd ","").replace('muhammad','').replace('mohammad','').replace('mohammed','').replace('muhammed','').replace('abdul ','').replace('m / s ','').replace('m/s ','').replace('director ','').replace('nideshak ','').replace('general ','').replace('manager ','').replace('finance ','').replace('proprietor ','').replace('managing ','').replace('chairman ','').replace('adhikrt ','').replace('hastakshari ','').replace('Phoorakan','Furkan').replace('Pradip','Pradeep').replace('Sarapharaj','Sarfaraz').replace('Rupakishor','Rupkishor').replace('Ashik','Ashiq').replace('Khurashid','Khurasheed').replace('Aphajad ','afjad').replace('Jagadish','Jagdish').replace('Krrishn','Krishn').replace('0','.').replace('Mau.','Md. ').replace('Mu.','Md. ').replace('Julphukar','Zulfukar').replace('Raphik','Rafiq').replace('ॉ','n').replace('Nur','Noor').replace('.D','d').replace('Chakamarg','Chakmarg').replace('Phaijan','Faizan').replace('Rahaman','Rahman').replace('Chakarod','Chakrod').replace('Sviti','Sweety').replace('ua','uya').replace('Aphasana','Afsana').replace('Ejaj','Ejaz').replace('Shahanavaj','Shahnavaj').replace('Virendr','Virendra').replace('Krrishna','Krishn').replace('Meharaban','Meharban').replace('Rukasana','Ruksana').replace('Juber','Zuber').replace('Kamarej','Kamrej').replace('Vahida','Waheed').replace('Mahabub','Mahboob').replace('Jan','Jaan').replace('Jahir','Zaheer').replace('Dipak','Deepak').replace('Urf','or').replace('Ghanashyam','Ghanshyam').replace('Hashamat','Hashmat').replace('Akhatar','Akhtar').replace('Rajakumar','Rajkumar').replace('Begaraj','Begraj').replace('Haphij','Hafiz').replace('Ahatamam','Ahatmam').replace('Nussever','Nusavvar').replace('Janaki','Janki').replace('narayan',' narayan').replace("  ",' ').replace(".","").strip()
        p1 = str(pjz.split("//")[0].strip().split(" ")[0].lower())
        p2 = str(pjz.split("//")[1].strip().split(" ")[0].lower())
        b1 = str(bjz.split("//")[0].strip().split(" ")[0].lower())
        b2 = str(bjz.split("//")[1].strip().split(" ")[0].lower())
        if len(p1) <3:
            p1 = "No Data"
        if len(p2) <3:
            p2 = "No Data"
        if len(b1) <3:
            b1 = "No Data"
        if len(b2) <3:
            b2 = "No Data"
        if str(pjz).replace(" ",'').lower() == str(bjz).replace(" ",'').lower():
            print("in if condition of matching advance--Matched")
            mat = "Matched"
        elif (pjz.split("//")[0].split(" ")[0].lower() == bjz.split("//")[0].split(" ")[0].lower()) and (pjz.split("//")[1].split(" ")[0].lower() == bjz.split("//")[1].split(" ")[0].lower()):
            print("in second condition of matching advance--matched")
            mat = "Matched"
        elif p2 != "No Data":
            print("in matching advance, if father name is present")
            if s.sounds_like(p1,b1) and (s.sounds_like(p2,b2) or (m.distance(p2,b2) <2 and r.distance(p2,b2) <2)):
                mat = "Matched"
        elif p2 == "No Data":
            print("in matching advance, if father name is not present")

            if str(pjz.split("//")[0].strip()).lower() == str(bjz.split("//")[0].strip()).lower():
                mat = "Matched"
        return mat
    client = pymongo.MongoClient("mongodb://"+str(ip)+":27017")
    db = client[str(databaseName)]
    s = Soundex()
    m = Metaphone()
    r = RefinedSoundex()

    if villageCodeList != ['string']:
        villageCodeList = [str(item).zfill(6) for item in villageCodeList]
        bdatay = pd.DataFrame(list(db[uniqueFarmerCollection].find({"villageCode":{"$in":villageCodeList}})))
        
        bdatay = pd.DataFrame(list(db[uniqueFarmerCollection].find({})))
        
        pdata = pd.DataFrame(list(db[pmKisanDataCollection].find({"villageCode":{"$in":villageCodeList}})))
        bdatay["villageCode"] = [str(item).zfill(6) for item in bdatay["villageCode"]]
        pdata["villageCode"] = [str(item).zfill(6) for item in pdata["villageCode"]]
        bdatay["tehsilCode"] = [str(item).zfill(5) for item in bdatay["tehsilCode"]]
        pdata["tehsilCode"] = [str(item).zfill(5) for item in pdata["tehsilCode"]]
        villageCodeList = list(pdata["villageCode"].unique())
        tehsilCodeList = list(pdata["tehsilCode"].unique())
        villageCodeList = [str(item).zfill(6) for item in villageCodeList]
        try:
            villageCodeList1 = list(map(str,list(map(int, villageCodeList))))
        except:
            pass
        if len(pdata) == 0:
            pdata = pd.DataFrame(list(db[pmKisanDataCollection].find({"villageCode":{"$in":villageCodeList1}})))
    else:
        bdatay = pd.DataFrame(list(db[uniqueFarmerCollection].find({})))
        pdata = pd.DataFrame(list(db[pmKisanDataCollection].find({})))
        bdatay["villageCode"] = [str(item).zfill(6) for item in bdatay["villageCode"]]
        pdata["villageCode"] = [str(item).zfill(6) for item in pdata["villageCode"]]
        bdatay["tehsilCode"] = [str(item).zfill(5) for item in bdatay["tehsilCode"]]
        pdata["tehsilCode"] = [str(item).zfill(5) for item in pdata["tehsilCode"]]
        villageCodeList = list(pdata["villageCode"].unique())
        tehsilCodeList = list(pdata["tehsilCode"].unique())
        villageCodeList = [str(item).zfill(6) for item in villageCodeList]
    bdatay = bdatay.fillna("")
    pdata = pdata.fillna("")
    bdatay = bdatay.astype(str)
    pdata = pdata.astype(str)
    lis = sorted(villageCodeList)
    dfz = pd.DataFrame()
    lisnz = []
    if len(bdatay)>0 and len(pdata)>0:
        for ni in lis:
            try:
                lisnz.append(ni)
                datay = bdatay[bdatay["villageCode"]==str(ni)]
                datay = bdatay[bdatay["tehsilCode"]==str(datay["tehsilCode"].unique()[0])]
                datay = datay[datay['ownerShip'].isin(["Private","निजी"])]
                bdatax = datay[datay.notna()]
                bdatax['villageCode'] = bdatax['villageCode'].astype(str)
                pdata['villageCode'] = pdata['villageCode'].astype(str)
                bdatan = bdatax[["farmerName","fatherName","khataNumber","khasraNumber","areas","areaInHectare","village","villageCode"]].sort_values(by = ["farmerName","fatherName"],ascending = [True, False]).reset_index(drop=True)
                pdatanx = pdata[pdata["villageCode"]==str(ni)]
                pdatanxz = pdatanx[["farmerName","fatherName","pmKisanID","mobileNumber","identityNumber"]].sort_values(by = ["farmerName","fatherName"],ascending = [True, False]).reset_index(drop=True)
                bdatan = bdatan.rename(columns = {"farmerName":"farmerName","fatherName":"fatherName"})
                pdatan = pdatanxz.rename(columns = {"farmerName":"farmerName","fatherName":"fatherName"})
                pdatan["farmerName"].fillna("No Data",inplace=True)
                pdatan["fatherName"].fillna("No Data",inplace=True)
                bdatan["farmerName"].fillna("No Data",inplace=True)
                bdatan["fatherName"].fillna("No Data",inplace=True)
                pdatan["fatherName"] = pdatan["fatherName"].str.replace("[A-Z][/][A-Z]|:","",regex=True).replace("S/O","").replace("C/O","").replace("W/O","").replace("  "," ",regex=False)
                pdatan["fatherName"] = pdatan["fatherName"].str.strip()
                pdatan["farmerName"],pdatan["fatherName"],bdatan["farmerName"],bdatan["fatherName"] = pdatan["farmerName"].str.strip(),pdatan["fatherName"].str.strip(),bdatan["farmerName"].str.strip(),bdatan["fatherName"].str.strip()
                pdatanz = pdatan["farmerName"] + "//" + pdatan["fatherName"]
                bdatanz = bdatan["farmerName"] + "//" + bdatan["fatherName"]
                df = pd.DataFrame()
                pdatanz.dropna(inplace=True)
                bdatanz.dropna(inplace=True)
                for pi,pj in enumerate(pdatanz):
                    id = False
                    for bi,bj in enumerate(bdatanz):
                        try:
                            pjz = pj.lower().replace("oo","u").replace("phul","ful").replace("ee","i").replace("ji ","jee").replace("a.","").replace("wati","vati").replace('md.','').replace("mohd ","").replace('muhammad','').replace('mohammad','').replace('mohammed','').replace('muhammed','').replace('abdul ','').replace('m / s ','').replace('m/s ','').replace('director ','').replace('nideshak ','').replace('general ','').replace('manager ','').replace('finance ','').replace('proprietor ','').replace('managing ','').replace('chairman ','').replace('adhikrt ','').replace('hastakshari ','').replace('Phoorakan','Furkan').replace('Pradip','Pradeep').replace('Sarapharaj','Sarfaraz').replace('Rupakishor','Rupkishor').replace('Ashik','Ashiq').replace('Khurashid','Khurasheed').replace('Aphajad ','afjad').replace('Jagadish','Jagdish').replace('Krrishn','Krishn').replace('0','.').replace('Mau.','Md. ').replace('Mu.','Md. ').replace('Julphukar','Zulfukar').replace('Raphik','Rafiq').replace('ॉ','n').replace('Nur','Noor').replace('.D','d').replace('Chakamarg','Chakmarg').replace('Phaijan','Faizan').replace('Rahaman','Rahman').replace('Chakarod','Chakrod').replace('Sviti','Sweety').replace('ua','uya').replace('Aphasana','Afsana').replace('Ejaj','Ejaz').replace('Shahanavaj','Shahnavaj').replace('Virendr','Virendra').replace('Krrishna','Krishn').replace('Meharaban','Meharban').replace('Rukasana','Ruksana').replace('Juber','Zuber').replace('Kamarej','Kamrej').replace('Vahida','Waheed').replace('Mahabub','Mahboob').replace('Jan','Jaan').replace('Jahir','Zaheer').replace('Dipak','Deepak').replace('Urf','or').replace('Ghanashyam','Ghanshyam').replace('Hashamat','Hashmat').replace('Akhatar','Akhtar').replace('Rajakumar','Rajkumar').replace('Begaraj','Begraj').replace('Haphij','Hafiz').replace('Ahatamam','Ahatmam').replace('Nussever','Nusavvar').replace('Janaki','Janki').replace('narayan',' narayan').replace("  ",' ').replace(".","").strip()
                            bjz = bj.lower().replace("oo","u").replace("phul","ful").replace("ee","i").replace("ji ","jee").replace("a.","").replace("wati","vati").replace('md.','').replace("mohd ","").replace('muhammad','').replace('mohammad','').replace('mohammed','').replace('muhammed','').replace('abdul ','').replace('m / s ','').replace('m/s ','').replace('director ','').replace('nideshak ','').replace('general ','').replace('manager ','').replace('finance ','').replace('proprietor ','').replace('managing ','').replace('chairman ','').replace('adhikrt ','').replace('hastakshari ','').replace('Phoorakan','Furkan').replace('Pradip','Pradeep').replace('Sarapharaj','Sarfaraz').replace('Rupakishor','Rupkishor').replace('Ashik','Ashiq').replace('Khurashid','Khurasheed').replace('Aphajad ','afjad').replace('Jagadish','Jagdish').replace('Krrishn','Krishn').replace('0','.').replace('Mau.','Md. ').replace('Mu.','Md. ').replace('Julphukar','Zulfukar').replace('Raphik','Rafiq').replace('ॉ','n').replace('Nur','Noor').replace('.D','d').replace('Chakamarg','Chakmarg').replace('Phaijan','Faizan').replace('Rahaman','Rahman').replace('Chakarod','Chakrod').replace('Sviti','Sweety').replace('ua','uya').replace('Aphasana','Afsana').replace('Ejaj','Ejaz').replace('Shahanavaj','Shahnavaj').replace('Virendr','Virendra').replace('Krrishna','Krishn').replace('Meharaban','Meharban').replace('Rukasana','Ruksana').replace('Juber','Zuber').replace('Kamarej','Kamrej').replace('Vahida','Waheed').replace('Mahabub','Mahboob').replace('Jan','Jaan').replace('Jahir','Zaheer').replace('Dipak','Deepak').replace('Urf','or').replace('Ghanashyam','Ghanshyam').replace('Hashamat','Hashmat').replace('Akhatar','Akhtar').replace('Rajakumar','Rajkumar').replace('Begaraj','Begraj').replace('Haphij','Hafiz').replace('Ahatamam','Ahatmam').replace('Nussever','Nusavvar').replace('Janaki','Janki').replace('narayan',' narayan').replace("  ",' ').replace(".","").strip()
                            p1 = str(pjz.split("//")[0].strip().split(" ")[0].lower())
                            p2 = str(pjz.split("//")[1].strip().split(" ")[0].lower())
                            b1 = str(bjz.split("//")[0].strip().split(" ")[0].lower())
                            b2 = str(bjz.split("//")[1].strip().split(" ")[0].lower())
                            if len(p1) <3:
                                p1 = "No Data"
                            if len(p2) <3:
                                p2 = "No Data"
                            if len(b1) <3:
                                b1 = "No Data"
                            if len(b2) <3:
                                b2 = "No Data"
                            if str(pjz).replace(" ",'').lower() == str(bjz).replace(" ",'').lower():
                                df.at[pi,"pmFarmer"] =str(pj.split("//")[0])
                                df.at[pi,"pmFather"] =str(pj.split("//")[1])
                                df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                df.at[pi,"Matching"] = "Matched"
                                bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])
                                df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi])    
                                df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi])
                                df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])    
                                df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                # df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])               
                                id = True
                            elif (str(pjz.split("//")[1]).replace(" ",'').lower() == str(bjz.split("//")[1]).replace(" ",'').lower()) and (r.sounds_like(p1,b1)):
                                df.at[pi,"pmFarmer"] =str(pj.split("//")[0])
                                df.at[pi,"pmFather"] =str(pj.split("//")[1])
                                df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                df.at[pi,"Matching"] = "Matched"
                                bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])  
                                df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi])    
                                df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi]) 
                                df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])       
                                df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                # df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])                                          
                                id = True
                            elif p1 != "No Data" and p2 != "No Data" and b1 != "No Data" and b2 != "No Data":
                                if r.sounds_like(str(pjz.split("//")[1]).replace(" ","").lower(),str(bjz.split("//")[1]).replace(" ","").lower()):
                                    if s.sounds_like(str(pjz.split("//")[0]).replace(" ","").lower(),str(bjz.split("//")[0]).replace(" ","").lower()):
                                        df.at[pi,"pmFarmer"] =str(pj.split("//")[0])
                                        df.at[pi,"pmFather"] =str(pj.split("//")[1])
                                        df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                        df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                        df.at[pi,"Matching"] = "Matched"
                                        bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                        pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                        df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                        df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])  
                                        df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                        df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi])    
                                        df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                        df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi])  
                                        df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                        df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])
                                        df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                        # df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])    
                                        id = True
                                elif (len(pjz.split("//")[0].split(" ")) == 1 or len(bjz.split("//")[0].split(" ")) ==1) and (len(pjz.split("//")[1].split(" ")) == 1 or len(bjz.split("//")[1].split(" ")) ==1):
                                    if r.sounds_like(p1,b1) and r.sounds_like(p2,b2):
                                        df.at[pi,"pmFarmer"] =str(pj.split("//")[0])
                                        df.at[pi,"pmFather"] =str(pj.split("//")[1])
                                        df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                        df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                        df.at[pi,"Matching"] = "Matched"
                                        bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                        pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                        df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                        df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi]) 
                                        df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                        df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi])    
                                        df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                        df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi])   
                                        df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                        df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])     
                                        df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                        # df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])              
                                        id = True       
                        except:
                            pass
                    if id == False:
                        df.at[pi,"pmFarmer"] =str(pj.split("//")[0])
                        df.at[pi,"pmFather"] =str(pj.split("//")[1])
                        df.at[pi,"bhulekhFarmer"] = ""
                        df.at[pi,"bhulekhFather"] = ""
                        df.at[pi,"Matching"] = ""
                        df.at[pi,"khataNumber"] = ""
                        df.at[pi,"khsaraNumber"] = ""
                        df.at[pi,"bvillageName"] = ""    
                        df.at[pi,"bvillageCode"] = "" 
                        df.at[pi,"areas"] = ""
                        df.at[pi,"areaInHectare"] = ""
                        df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                        df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])  
                        df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                        #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])

                for pi,pj in enumerate(pdatanz):
                    if pdatanz[pi] != "Entry_Matched//Entry_Matched":
                        id = False
                        for bi,bj in enumerate(bdatanz):
                            if bdatanz[bi] != "Entry_Matched//Entry_Matched":
                                try:
                                    pjz = pj.lower().replace("oo","u").replace("ee","i").replace("dra","der").replace("a.","").replace("phul","ful").replace("wati","vati").replace('md.','').replace("mohd ","").replace('muhammad','').replace('mohammad','').replace('mohammed','').replace('muhammed','').replace('abdul ','').replace('m / s ','').replace('m/s ','').replace('director ','').replace('nideshak ','').replace('general ','').replace('manager ','').replace('finance ','').replace('proprietor ','').replace('managing ','').replace('chairman ','').replace('adhikrt ','').replace('hastakshari ','').replace('Phoorakan','Furkan').replace('Pradip','Pradeep').replace('Sarapharaj','Sarfaraz').replace('Rupakishor','Rupkishor').replace('Ashik','Ashiq').replace('Khurashid','Khurasheed').replace('Aphajad ','afjad').replace('Jagadish','Jagdish').replace('Krrishn','Krishn').replace('0','.').replace('Mau.','Md. ').replace('Mu.','Md. ').replace('Julphukar','Zulfukar').replace('Raphik','Rafiq').replace('ॉ','n').replace('Nur','Noor').replace('.D','d').replace('Chakamarg','Chakmarg').replace('Phaijan','Faizan').replace('Rahaman','Rahman').replace('Chakarod','Chakrod').replace('Sviti','Sweety').replace('ua','uya').replace('Aphasana','Afsana').replace('Ejaj','Ejaz').replace('Shahanavaj','Shahnavaj').replace('Virendr','Virendra').replace('Krrishna','Krishn').replace('Meharaban','Meharban').replace('Rukasana','Ruksana').replace('Juber','Zuber').replace('Kamarej','Kamrej').replace('Vahida','Waheed').replace('Mahabub','Mahboob').replace('Jan','Jaan').replace('Jahir','Zaheer').replace('Dipak','Deepak').replace('Urf','or').replace('Ghanashyam','Ghanshyam').replace('Hashamat','Hashmat').replace('Akhatar','Akhtar').replace('Rajakumar','Rajkumar').replace('Begaraj','Begraj').replace('Haphij','Hafiz').replace('Ahatamam','Ahatmam').replace('Nussever','Nusavvar').replace('Janaki','Janki').replace('narayan',' narayan').replace("  ",' ').replace(".","").strip()
                                    bjz = bj.lower().replace("oo","u").replace("ee","i").replace("dra","der").replace("a.","").replace("phul","ful").replace("wati","vati").replace('md.','').replace("mohd ","").replace('muhammad','').replace('mohammad','').replace('mohammed','').replace('muhammed','').replace('abdul ','').replace('m / s ','').replace('m/s ','').replace('director ','').replace('nideshak ','').replace('general ','').replace('manager ','').replace('finance ','').replace('proprietor ','').replace('managing ','').replace('chairman ','').replace('adhikrt ','').replace('hastakshari ','').replace('Phoorakan','Furkan').replace('Pradip','Pradeep').replace('Sarapharaj','Sarfaraz').replace('Rupakishor','Rupkishor').replace('Ashik','Ashiq').replace('Khurashid','Khurasheed').replace('Aphajad ','afjad').replace('Jagadish','Jagdish').replace('Krrishn','Krishn').replace('0','.').replace('Mau.','Md. ').replace('Mu.','Md. ').replace('Julphukar','Zulfukar').replace('Raphik','Rafiq').replace('ॉ','n').replace('Nur','Noor').replace('.D','d').replace('Chakamarg','Chakmarg').replace('Phaijan','Faizan').replace('Rahaman','Rahman').replace('Chakarod','Chakrod').replace('Sviti','Sweety').replace('ua','uya').replace('Aphasana','Afsana').replace('Ejaj','Ejaz').replace('Shahanavaj','Shahnavaj').replace('Virendr','Virendra').replace('Krrishna','Krishn').replace('Meharaban','Meharban').replace('Rukasana','Ruksana').replace('Juber','Zuber').replace('Kamarej','Kamrej').replace('Vahida','Waheed').replace('Mahabub','Mahboob').replace('Jan','Jaan').replace('Jahir','Zaheer').replace('Dipak','Deepak').replace('Urf','or').replace('Ghanashyam','Ghanshyam').replace('Hashamat','Hashmat').replace('Akhatar','Akhtar').replace('Rajakumar','Rajkumar').replace('Begaraj','Begraj').replace('Haphij','Hafiz').replace('Ahatamam','Ahatmam').replace('Nussever','Nusavvar').replace('Janaki','Janki').replace('narayan',' narayan').replace("  ",' ').replace(".","").strip()
                                    p1 = str(pjz.split("//")[0].strip().split(" ")[0].lower())
                                    p2 = str(pjz.split("//")[1].strip().split(" ")[0].lower())
                                    b1 = str(bjz.split("//")[0].strip().split(" ")[0].lower())
                                    b2 = str(bjz.split("//")[1].strip().split(" ")[0].lower())
                                    if len(p1) <3:
                                        p1 = "No Data"
                                    if len(p2) <3:
                                        p2 = "No Data"
                                    if len(b1) <3:
                                        b1 = "No Data"
                                    if len(b2) <3:
                                        b2 = "No Data"

                                    if str(pjz).replace(" ",'').lower() == str(bjz).replace(" ",'').lower():
                                        df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                        df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                        df.at[pi,"Matching"] = "Matched"
                                        bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                        pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                        df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                        df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])  
                                        df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                        df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi])   
                                        df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                        df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi])   
                                        df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                        df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])     
                                        df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                        #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])             
                                        id = True

                                    elif (pjz.split("//")[0].split(" ")[0].lower() == bjz.split("//")[0].split(" ")[0].lower()) and (pjz.split("//")[1].split(" ")[0].lower() == bjz.split("//")[1].split(" ")[0].lower()) and id == False:
                                        try:
                                            df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                            df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                            df.at[pi,"Matching"] = "Matched"
                                            bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                            pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                            df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                            df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])  
                                            df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                            df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi])  
                                            df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                            df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])     
                                            df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                            #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])  
                                            id = True
                                        except:
                                            pass
                                    elif id == False and p2 != "No Data":
                                        try:
                                            if matching(pjz,bjz) =="Matched" :
                                                df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                                df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                                df.at[pi,"Matching"] = "Matched"
                                                bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                                pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                                df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                                df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])  
                                                df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                                df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi])   
                                                df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                                df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi])    
                                                df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                                df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])  
                                                df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                                #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi]) 
                                                id = True
                                            elif matchingadv(pjz,bjz) =="Matched" :
                                                df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                                df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                                df.at[pi,"Matching"] = "Matched"
                                                bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                                pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                                df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                                df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi]) 
                                                df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                                df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi])   
                                                df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                                df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi])   
                                                df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                                df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])
                                                df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                                #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])    
                                                id = True
                                            elif (pjz.split("//")[1] == bjz.split("//")[1]) and (jellyfish.jaro_winkler(p1, b1) > 0.95):
                                                df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                                df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                                df.at[pi,"Matching"] = "Matched"
                                                bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                                pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                                df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                                df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi]) 
                                                df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                                df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi])   
                                                df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                                df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi]) 
                                                df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                                df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])  
                                                df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                                #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])   
                                                id = True
                                        except:
                                            pass

                                    elif id == False and p2 == "No Data":
                                        try:
                                            if str(bjz.replace('//',"").replace(" ","").lower()) == str(pjz.split("//")[0].replace(" ","").lower()):
                                                df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                                df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                                df.at[pi,"Matching"] = "Matched"
                                                bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                                pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                                df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                                df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])  
                                                df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                                df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi])  
                                                df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                                df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi]) 
                                                df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                                df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi]) 
                                                df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                                #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])      
                                                id = True
                                            elif str(pjz.split("//")[0].strip()).lower() == str(bjz.split("//")[0].strip()).lower():
                                                df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                                df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                                df.at[pi,"Matching"] = "Matched"
                                                bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                                pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                                df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                                df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])
                                                df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                                df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi])    
                                                df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                                df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi])   
                                                df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                                df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])  
                                                df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                                #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi]) 
                                                id = True
                                            elif str(pjz.split("//")[0]) == str(bjz.split("//")[0]):
                                                df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                                df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                                df.at[pi,"Matching"] = "Matched"
                                                bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                                pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                                df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                                df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi]) 
                                                df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                                df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi])   
                                                df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                                df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi])  
                                                df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                                df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi]) 
                                                df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                                #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])   
                                                id = True
                                            elif p2== "No Data" and r.sounds_like(str(pjz.split("//")[0]),str(bjz.split("//")[0])):
                                                df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                                df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                                df.at[pi,"Matching"] = "Matched"
                                                bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                                pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                                df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                                df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])
                                                df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                                df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi])    
                                                df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                                df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi]) 
                                                df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                                df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])   
                                                df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                                #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])  
                                                id = True 
                                        except:
                                            pass
                                except:
                                    pass
                            
                                        
                for pi,pj in enumerate(pdatanz):
                    if pdatanz[pi] != "Entry_Matched//Entry_Matched":
                        id = False
                        for bi,bj in enumerate(bdatanz):
                            try:
                                if bdatanz[bi] != "Entry_Matched//Entry_Matched":
                                    pjz = pj.lower().replace("oo","u").replace("ee","i").replace("dra","der").replace("a.","").replace("phul","ful").replace("wati","vati").replace('md.','').replace("mohd ","").replace('muhammad','').replace('mohammad','').replace('mohammed','').replace('muhammed','').replace('abdul ','').replace('m / s ','').replace('m/s ','').replace('director ','').replace('nideshak ','').replace('general ','').replace('manager ','').replace('finance ','').replace('proprietor ','').replace('managing ','').replace('chairman ','').replace('adhikrt ','').replace('hastakshari ','').replace('Phoorakan','Furkan').replace('Pradip','Pradeep').replace('Sarapharaj','Sarfaraz').replace('Rupakishor','Rupkishor').replace('Ashik','Ashiq').replace('Khurashid','Khurasheed').replace('Aphajad ','afjad').replace('Jagadish','Jagdish').replace('Krrishn','Krishn').replace('0','.').replace('Mau.','Md. ').replace('Mu.','Md. ').replace('Julphukar','Zulfukar').replace('Raphik','Rafiq').replace('ॉ','n').replace('Nur','Noor').replace('.D','d').replace('Chakamarg','Chakmarg').replace('Phaijan','Faizan').replace('Rahaman','Rahman').replace('Chakarod','Chakrod').replace('Sviti','Sweety').replace('ua','uya').replace('Aphasana','Afsana').replace('Ejaj','Ejaz').replace('Shahanavaj','Shahnavaj').replace('Virendr','Virendra').replace('Krrishna','Krishn').replace('Meharaban','Meharban').replace('Rukasana','Ruksana').replace('Juber','Zuber').replace('Kamarej','Kamrej').replace('Vahida','Waheed').replace('Mahabub','Mahboob').replace('Jan','Jaan').replace('Jahir','Zaheer').replace('Dipak','Deepak').replace('Urf','or').replace('Ghanashyam','Ghanshyam').replace('Hashamat','Hashmat').replace('Akhatar','Akhtar').replace('Rajakumar','Rajkumar').replace('Begaraj','Begraj').replace('Haphij','Hafiz').replace('Ahatamam','Ahatmam').replace('Nussever','Nusavvar').replace('Janaki','Janki').replace('narayan',' narayan').replace("  ",' ').replace(".","").strip()
                                    bjz = bj.lower().replace("oo","u").replace("ee","i").replace("dra","der").replace("a.","").replace("phul","ful").replace("wati","vati").replace('md.','').replace("mohd ","").replace('muhammad','').replace('mohammad','').replace('mohammed','').replace('muhammed','').replace('abdul ','').replace('m / s ','').replace('m/s ','').replace('director ','').replace('nideshak ','').replace('general ','').replace('manager ','').replace('finance ','').replace('proprietor ','').replace('managing ','').replace('chairman ','').replace('adhikrt ','').replace('hastakshari ','').replace('Phoorakan','Furkan').replace('Pradip','Pradeep').replace('Sarapharaj','Sarfaraz').replace('Rupakishor','Rupkishor').replace('Ashik','Ashiq').replace('Khurashid','Khurasheed').replace('Aphajad ','afjad').replace('Jagadish','Jagdish').replace('Krrishn','Krishn').replace('0','.').replace('Mau.','Md. ').replace('Mu.','Md. ').replace('Julphukar','Zulfukar').replace('Raphik','Rafiq').replace('ॉ','n').replace('Nur','Noor').replace('.D','d').replace('Chakamarg','Chakmarg').replace('Phaijan','Faizan').replace('Rahaman','Rahman').replace('Chakarod','Chakrod').replace('Sviti','Sweety').replace('ua','uya').replace('Aphasana','Afsana').replace('Ejaj','Ejaz').replace('Shahanavaj','Shahnavaj').replace('Virendr','Virendra').replace('Krrishna','Krishn').replace('Meharaban','Meharban').replace('Rukasana','Ruksana').replace('Juber','Zuber').replace('Kamarej','Kamrej').replace('Vahida','Waheed').replace('Mahabub','Mahboob').replace('Jan','Jaan').replace('Jahir','Zaheer').replace('Dipak','Deepak').replace('Urf','or').replace('Ghanashyam','Ghanshyam').replace('Hashamat','Hashmat').replace('Akhatar','Akhtar').replace('Rajakumar','Rajkumar').replace('Begaraj','Begraj').replace('Haphij','Hafiz').replace('Ahatamam','Ahatmam').replace('Nussever','Nusavvar').replace('Janaki','Janki').replace('narayan',' narayan').replace("  ",' ').replace(".","").strip()
                                    p1 = str(pjz.split("//")[0].strip().split(" ")[0].lower())
                                    p2 = str(pjz.split("//")[1].strip().split(" ")[0].lower())
                                    b1 = str(bjz.split("//")[0].strip().split(" ")[0].lower())
                                    b2 = str(bjz.split("//")[1].strip().split(" ")[0].lower())
                                    if len(p1) <3:
                                        p1 = "No Data"
                                    if len(p2) <3:
                                        p2 = "No Data"
                                    if len(b1) <3:
                                        b1 = "No Data"
                                    if len(b2) <3:
                                        b2 = "No Data"  
                                    if p2!= "No Data" and s.sounds_like(p1,b1) and r.sounds_like(p2,b2):
                                        df.at[pi,"pmFarmer"] =str(pj.split("//")[0])
                                        df.at[pi,"pmFather"] =str(pj.split("//")[1])
                                        df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                        df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                        df.at[pi,"Matching"] = "Matched"
                                        bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                        pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                        df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                        df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])  
                                        df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                        df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi])  
                                        df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                        df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi])     
                                        df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                        df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])   
                                        df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                        #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])              
                                        id = True      
                                    elif p2!= "No Data" and (p1 in b1) and r.sounds_like(p2,b2):
                                        df.at[pi,"pmFarmer"] =str(pj.split("//")[0])
                                        df.at[pi,"pmFather"] =str(pj.split("//")[1])
                                        df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                        df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                        df.at[pi,"Matching"] = "Matched"
                                        bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                        pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                        df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                        df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])  
                                        df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                        df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi]) 
                                        df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                        df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi])     
                                        df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                        df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi]) 
                                        df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                        #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])                 
                                        id = True   
                                    elif p2!= "No Data" and jellyfish.jaro_winkler(p1,b1)>0.9 and s.sounds_like(p2,b2):
                                        df.at[pi,"pmFarmer"] =str(pj.split("//")[0])
                                        df.at[pi,"pmFather"] =str(pj.split("//")[1])
                                        df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                        df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                        df.at[pi,"Matching"] = "Matched"
                                        bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                        pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                        df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                        df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])
                                        df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                        df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi])   
                                        df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                        df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi])
                                        df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                        df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])      
                                        df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                        #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])                 
                                        id = True
                                    elif p2!= "No Data" and r.sounds_like(p1,b1) and s.sounds_like(p2,b2):
                                        df.at[pi,"pmFarmer"] =str(pj.split("//")[0])
                                        df.at[pi,"pmFather"] =str(pj.split("//")[1])
                                        df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                        df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                        df.at[pi,"Matching"] = "Matched"
                                        bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                        pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                        df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                        df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])  
                                        df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                        df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi]) 
                                        df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                        df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi])
                                        df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                        df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])      
                                        df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                        #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])                 
                                        id = True  

                                    elif p2== "No Data" and r.sounds_like(p1,b1) and jellyfish.jaro_winkler(p1,b1)>0.9:
                                        df.at[pi,"pmFarmer"] =str(pj.split("//")[0])
                                        df.at[pi,"pmFather"] =str(pj.split("//")[1])
                                        df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                        df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                        df.at[pi,"Matching"] = "Matched"
                                        bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                        pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                        df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                        df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])  
                                        df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                        df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi]) 
                                        df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                        df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi]) 
                                        df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                        df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])   
                                        df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                        #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])   
                                        id = True  
                                    elif p2== "No Data" and p1 == b1 and jellyfish.jaro_winkler(p1,b1)>0.85:
                                        df.at[pi,"pmFarmer"] =str(pj.split("//")[0])
                                        df.at[pi,"pmFather"] =str(pj.split("//")[1])
                                        df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                        df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                        df.at[pi,"Matching"] = "Matched"
                                        bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                        pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                        df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                        df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])  
                                        df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                        df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi]) 
                                        df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                        df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi]) 
                                        df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                        df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])   
                                        df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                        #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])   
                                        id = True    
                                    elif p2== "No Data" and s.phonetics(p1)==s.phonetics(b1) and jellyfish.jaro_winkler(p1,b1)>0.9:
                                        df.at[pi,"pmFarmer"] =str(pj.split("//")[0])
                                        df.at[pi,"pmFather"] =str(pj.split("//")[1])
                                        df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                        df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                        df.at[pi,"Matching"] = "Matched"
                                        bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                        pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                        df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                        df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])  
                                        df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                        df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi]) 
                                        df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                        df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi]) 
                                        df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                        df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])  
                                        df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                        #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])    
                                        id = True    
                                    elif p2== "No Data" and s.phonetics(p1)==s.phonetics(b1) and jellyfish.jaro_winkler(p1,b1)>0.9:
                                        df.at[pi,"pmFarmer"] =str(pj.split("//")[0])
                                        df.at[pi,"pmFather"] =str(pj.split("//")[1])
                                        df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                        df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                        df.at[pi,"Matching"] = "Matched"
                                        bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                        pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                        df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                        df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi])  
                                        df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                        df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi]) 
                                        df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                        df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi]) 
                                        df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                        df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])
                                        df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                        #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])     
                                        id = True    
                            except:
                                pass   
                for pi,pj in enumerate(pdatanz):
                    if pdatanz[pi] != "Entry_Matched//Entry_Matched":
                        id = False
                        for bi,bj in enumerate(bdatanz):
                            try:
                                if bdatanz[bi] != "Entry_Matched//Entry_Matched":
                                    pjz = pj.lower().replace("oo","u").replace("phul","ful").replace("ee","i").replace("ji ","jee").replace("a.","").replace("wati","vati").replace('md.','').replace("mohd ","").replace('muhammad','').replace('mohammad','').replace('mohammed','').replace('muhammed','').replace('abdul ','').replace('m / s ','').replace('m/s ','').replace('director ','').replace('nideshak ','').replace('general ','').replace('manager ','').replace('finance ','').replace('proprietor ','').replace('managing ','').replace('chairman ','').replace('adhikrt ','').replace('hastakshari ','').replace('Phoorakan','Furkan').replace('Pradip','Pradeep').replace('Sarapharaj','Sarfaraz').replace('Rupakishor','Rupkishor').replace('Ashik','Ashiq').replace('Khurashid','Khurasheed').replace('Aphajad ','afjad').replace('Jagadish','Jagdish').replace('Krrishn','Krishn').replace('0','.').replace('Mau.','Md. ').replace('Mu.','Md. ').replace('Julphukar','Zulfukar').replace('Raphik','Rafiq').replace('ॉ','n').replace('Nur','Noor').replace('.D','d').replace('Chakamarg','Chakmarg').replace('Phaijan','Faizan').replace('Rahaman','Rahman').replace('Chakarod','Chakrod').replace('Sviti','Sweety').replace('ua','uya').replace('Aphasana','Afsana').replace('Ejaj','Ejaz').replace('Shahanavaj','Shahnavaj').replace('Virendr','Virendra').replace('Krrishna','Krishn').replace('Meharaban','Meharban').replace('Rukasana','Ruksana').replace('Juber','Zuber').replace('Kamarej','Kamrej').replace('Vahida','Waheed').replace('Mahabub','Mahboob').replace('Jan','Jaan').replace('Jahir','Zaheer').replace('Dipak','Deepak').replace('Urf','or').replace('Ghanashyam','Ghanshyam').replace('Hashamat','Hashmat').replace('Akhatar','Akhtar').replace('Rajakumar','Rajkumar').replace('Begaraj','Begraj').replace('Haphij','Hafiz').replace('Ahatamam','Ahatmam').replace('Nussever','Nusavvar').replace('Janaki','Janki').replace('narayan',' narayan').replace("singh"," singh").replace("  ",' ').replace(".","").strip()
                                    bjz = bj.lower().replace("oo","u").replace("phul","ful").replace("ee","i").replace("ji ","jee").replace("a.","").replace("wati","vati").replace('md.','').replace("mohd ","").replace('muhammad','').replace('mohammad','').replace('mohammed','').replace('muhammed','').replace('abdul ','').replace('m / s ','').replace('m/s ','').replace('director ','').replace('nideshak ','').replace('general ','').replace('manager ','').replace('finance ','').replace('proprietor ','').replace('managing ','').replace('chairman ','').replace('adhikrt ','').replace('hastakshari ','').replace('Phoorakan','Furkan').replace('Pradip','Pradeep').replace('Sarapharaj','Sarfaraz').replace('Rupakishor','Rupkishor').replace('Ashik','Ashiq').replace('Khurashid','Khurasheed').replace('Aphajad ','afjad').replace('Jagadish','Jagdish').replace('Krrishn','Krishn').replace('0','.').replace('Mau.','Md. ').replace('Mu.','Md. ').replace('Julphukar','Zulfukar').replace('Raphik','Rafiq').replace('ॉ','n').replace('Nur','Noor').replace('.D','d').replace('Chakamarg','Chakmarg').replace('Phaijan','Faizan').replace('Rahaman','Rahman').replace('Chakarod','Chakrod').replace('Sviti','Sweety').replace('ua','uya').replace('Aphasana','Afsana').replace('Ejaj','Ejaz').replace('Shahanavaj','Shahnavaj').replace('Virendr','Virendra').replace('Krrishna','Krishn').replace('Meharaban','Meharban').replace('Rukasana','Ruksana').replace('Juber','Zuber').replace('Kamarej','Kamrej').replace('Vahida','Waheed').replace('Mahabub','Mahboob').replace('Jan','Jaan').replace('Jahir','Zaheer').replace('Dipak','Deepak').replace('Urf','or').replace('Ghanashyam','Ghanshyam').replace('Hashamat','Hashmat').replace('Akhatar','Akhtar').replace('Rajakumar','Rajkumar').replace('Begaraj','Begraj').replace('Haphij','Hafiz').replace('Ahatamam','Ahatmam').replace('Nussever','Nusavvar').replace('Janaki','Janki').replace('narayan',' narayan').replace("singh"," singh").replace("  ",' ').replace(".","").strip()
                                    p1 = str(pjz.split("//")[0].strip().split(" ")[0].lower())
                                    p2 = str(pjz.split("//")[1].strip().split(" ")[0].lower())
                                    b1 = str(bjz.split("//")[0].strip().split(" ")[0].lower())
                                    b2 = str(bjz.split("//")[1].strip().split(" ")[0].lower())
                                    if len(p1) <3:
                                        p1 = "No Data"
                                    if len(p2) <3:
                                        p2 = "No Data"
                                    if len(b1) <3:
                                        b1 = "No Data"
                                    if len(b2) <3:
                                        b2 = "No Data"   

                                    if p2== "No Data" and jellyfish.jaro_winkler(p1,b1)>0.9:
                                        df.at[pi,"pmFarmer"] =str(pj.split("//")[0])
                                        df.at[pi,"pmFather"] =str(pj.split("//")[1])
                                        df.at[pi,"bhulekhFarmer"] = str(bj.split("//")[0])
                                        df.at[pi,"bhulekhFather"] = str(bj.split("//")[1])
                                        df.at[pi,"Matching"] = "Matched"
                                        bdatanz[bi] = "Entry_Matched//Entry_Matched"
                                        pdatanz[pi] = "Entry_Matched//Entry_Matched"
                                        df.at[pi,"khataNumber"] = str(bdatan["khataNumber"][bi]) 
                                        df.at[pi,"khsaraNumber"] = str(bdatan["khasraNumber"][bi]) 
                                        df.at[pi,"bvillageName"] = str(bdatan["village"][bi])    
                                        df.at[pi,"bvillageCode"] = str(bdatan["villageCode"][bi])  
                                        df.at[pi,"areas"] = str(bdatan["areas"][bi])   
                                        df.at[pi,"areaInHectare"] = str(bdatan["areaInHectare"][bi]) 
                                        df.at[pi,"pmKisanID"] = str(pdatanxz["pmKisanID"][pi])   
                                        df.at[pi,"mobileNumber"] = str(pdatanxz["mobileNumber"][pi])
                                        df.at[pi,"identityNumber"] = str(pdatanxz["identityNumber"][pi])   
                                        #df.at[pi,"fatherNameSource"] = str(pdatanxz["fatherNameSource"][pi])     
                                        id = True    
                            except:
                                pass               
                df['state'],df['stateCode'],df['city'],df['cityCode'],df['block'],df['blockCode'],df['tehsil'],df['tehsilCode'],df['village'],df['villageCode'] = str(bdatax['state'].values[0]),str(bdatax['stateCode'].values[0]),str(bdatax['city'].values[0]),str(bdatax['cityCode'].values[0]),str(pdatanx['block'].values[0]),str(pdatanx['blockCode'].values[0]),str(bdatax['tehsil'].values[0]),str(bdatax['tehsilCode'].values[0]),str(bdatax['village'].values[0]),str(bdatax['villageCode'].values[0])
                df = df.astype(str)
                db[pmKisanMatchingCollection].insert_many(df.to_dict('records'))
            except:
                lisnz.append('no_'+str(ni))
        return lisnz
    else:
        return "No Data Found"
